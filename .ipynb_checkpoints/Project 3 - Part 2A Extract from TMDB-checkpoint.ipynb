# %%
#!pip install tmdbsimple

# %%
import json
with open('/Users/Jeancarlo Garcia/.secret/tmdb_api.json') as f: #change the path to match YOUR path!!
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
import tmdbsimple as tmdb
tmdb.API_KEY =  login['api-key']

# %%
import os,time,json
import pandas as pd
from tqdm.notebook import tqdm_notebook
FOLDER = "Data/Movies Data"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'Movies Datacombined_tmdb_api_data.csv.gz',
#  'Movies Datatmdb_api_results_2000.json',
#  'Movies Datatmdb_api_results_2001.json',
#  'title_akas.csv.gz',
#  'title_basics.csv.gz',
#  'title_ratings.csv.gz']

# %% [markdown]
# ## Load Data

# %%
basics = pd.read_csv('Data/Movies Data/title_basics.csv.gz')
basics.info()
basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81768 entries, 0 to 81767
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          81768 non-null  object
#  1   titleType       81768 non-null  object
#  2   primaryTitle    81768 non-null  object
#  3   originalTitle   81768 non-null  object
#  4   isAdult         81768 non-null  int64
#  5   startYear       81768 non-null  float64
#  6   runtimeMinutes  81768 non-null  int64
#  7   genres          81768 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 5.0+ MB
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# ...

# %% [markdown]
# ## Functions for API Extract

# %%
def get_movie_with_rating(movie_id):
    # Get the movie object for the current id
    movie = tmdb.Movies(movie_id)
    # Construct output dict
    movie_info = movie.info()
    releases = movie.releases()
    # Loop through countries in releases
    for c in releases['countries']:
        if c['iso_3166_1' ] =='US':
            ##"certification" key saved in the info dict with certification
            movie_info['certification'] = c['certification']
    return movie_info

# %%
# Proof of concept - Test years
YEARS_TO_GET = [2000,2001]
YEARS_TO_GET
# Out:
# [2000, 2001]

# %%
# OUTER loop

for YEAR in tqdm_notebook(YEARS_TO_GET,desc='YEARS',
                          position=0):
    

    #Saving new year as the current df
    df = basics.loc[ basics['startYear']==YEAR].copy()
    # saving movie ids to list
    movie_ids = df['tconst'].copy()#.to_list()

    #Defining the JSON file to store results for year
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'

    # Check if file exists
    file_exists = os.path.isfile(JSON_FILE)


    # If it does not exist: create it
    if file_exists == False:
        # save an empty dict with just "imdb_id" to the new json file.
        with open(JSON_FILE,'w') as f:
            json.dump([{'imdb_id':0}],f)


        # Load existing data from json into a dataframe called "previous_df"
        previous_df = pd.read_json(JSON_FILE)


        # filter out any ids that are already in the JSON_FILE
        movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]
################################################################################################
# INNER Loop

def write_json(new_data, filename): 
    """Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""    
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)  
        
   
     #Get index and movie id from list
    
    for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
        # Attempt to retrieve then data for the movie id
        try:
            temp = get_movie_with_rating(movie_id)  #This uses your pre-ma    de function
            # Append/extend results to existing file using a pre-made function
            
                
            write_json(temp,JSON_FILE)

            
            # Short 20 ms sleep to prevent overwhelming server
            time.sleep(0.02)

        # If it fails,  make a dict with just the id and None for certification
        except Exception as e:
            continue
            
####################################
    ## save compressed csv

    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)
# Out:
# YEARS:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ### Concatenation of TMDB Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
FOLDER = "Data/Movies Data"
sorted(os.listdir(FOLDER))
# Out:
# ['Movies Datacombined_tmdb_api_data.csv.gz',
#  'Movies Datatmdb_api_results_2000.json',
#  'Movies Datatmdb_api_results_2001.json',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'title_akas.csv.gz',
#  'title_basics.csv.gz',
#  'title_ratings.csv.gz']

# %%
df_tmdb_2000 = pd.read_csv('Data/Movies Data/final_tmdb_data_2000.csv.gz', lineterminator='\n')
df_tmdb_2000.head()
# Out:
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN  10000000
# 1  False                               NaN                   NaN         0
# 2  False                               NaN                   NaN         0
# 3  False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN    150000
# 4  False                               NaN                   NaN         0
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1           [{'id': 878, 'name': 'Science Fiction'}]
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4                      [{'id': 18, 'name': 'Drama'}]
#
#                                homepage      id    imdb_id original_language  \
# 0                                   NaN   62127  tt0113026                en
# ...

# %%
df_tmdb_2001 = pd.read_csv('Data/Movies Data/final_tmdb_data_2001.csv.gz')
df_tmdb_2001.head()
# Out:
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False  /ab5yL8zgRotrICzGbEl10z24N71.jpg                   NaN  48000000
# 1  False                               NaN                   NaN         0
# 2  False                               NaN                   NaN         0
# 3  False  /bLntSfsqUheiUirdV9Ts8znqsTM.jpg                   NaN  22000000
# 4  False  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN   1000000
#
#                                               genres homepage      id  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...      NaN   11232
# 1  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN  151007
# 2                [{'id': 99, 'name': 'Documentary'}]      NaN  292980
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   10696
# 4  [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...      NaN   17140
#
#      imdb_id original_language         original_title  \
# ...

# %%
df = pd.concat([df_tmdb_2000, df_tmdb_2001])
df
# Out:
#       adult                     backdrop_path belongs_to_collection    budget  \
# 0     False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN  10000000
# 1     False                               NaN                   NaN         0
# 2     False                               NaN                   NaN         0
# 3     False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN    150000
# 4     False                               NaN                   NaN         0
# ...     ...                               ...                   ...       ...
# 1453  False                               NaN                   NaN         0
# 1454  False                               NaN                   NaN         0
# 1455  False                               NaN                   NaN         0
# 1456  False                               NaN                   NaN         0
# 1457  False                               NaN                   NaN         0
#
# ...

# %% [markdown]
# ## Save Combined DataFrames to CSV

# %%
# Save combined dataframes to scv
fname =FOLDER+'combined_tmdb_api_data.csv.gz'
df.to_csv(fname,compression='gzip',index=False)
df = pd.read_csv(fname, lineterminator='\n')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2824 entries, 0 to 2823
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  2824 non-null   bool
#  1   backdrop_path          1309 non-null   object
#  2   belongs_to_collection  198 non-null    object
#  3   budget                 2824 non-null   int64
#  4   genres                 2824 non-null   object
#  5   homepage               223 non-null    object
#  6   id                     2824 non-null   int64
#  7   imdb_id                2824 non-null   object
#  8   original_language      2824 non-null   object
#  9   original_title         2824 non-null   object
#  10  overview               2764 non-null   object
#  11  popularity             2824 non-null   float64
#  12  poster_path            2398 non-null   object
#  13  production_companies   2824 non-null   object
# ...
