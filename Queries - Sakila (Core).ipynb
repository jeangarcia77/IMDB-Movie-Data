# %%
import pandas as pd

# %%
# !pip install pymysql

# %%
import pymysql
pymysql.install_as_MySQLdb()

# %%
from sqlalchemy import create_engine

# %%
# Create connection string using credentials following this format
# connection = "dialect+driver://username:password@host:port/database"

connection = "mysql+pymysql://root:root@localhost/sakila"

# %%
#To make the connection between python and MySQL, you will create an engine using the connection string you just defined.


engine = create_engine(connection)

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/sakila)

# %%
#Execute Query
#You can also execute any SQL query with pd.read_sql.
#Remember you can write multi-line strings by using triple quotes around it


q = """SELECT * FROM customer;"""
pd.read_sql(q, engine)
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              1         1       MARY      SMITH
# 1              2         1   PATRICIA    JOHNSON
# 2              3         1      LINDA   WILLIAMS
# 3              4         2    BARBARA      JONES
# 4              5         1  ELIZABETH      BROWN
# ..           ...       ...        ...        ...
# 594          595         1   TERRENCE  GUNDERSON
# 595          596         1    ENRIQUE   FORSYTHE
# 596          597         1    FREDDIE     DUGGAN
# 597          598         1       WADE   DELVALLE
# 598          599         2     AUSTIN    CINTRON
#
#                                      email  address_id  active  \
# 0            MARY.SMITH@sakilacustomer.org           5       1
# 1      PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 2        LINDA.WILLIAMS@sakilacustomer.org           7       1
# 3         BARBARA.JONES@sakilacustomer.org           8       1
# ...

# %% [markdown]
# ![png](https://s3.amazonaws.com/General_V88/boomyeah/company_209/chapter_3569/handouts/chapter3569_5431_sakila-db-model.png)

# %% [markdown]
# # Queries

# %% [markdown]
# 1. What query would you run to get all the customers inside city_id = 312?
# Your query should return the customers' first name, last name, email, address, and city.

# %%
c = """SELECT i.first_name,i.last_name,i.email,a.address,e.city,e.city_id
FROM customer i 
INNER JOIN address a ON a.address_id = i.customer_id
INNER JOIN city e ON e.city_id = i.customer_id
WHERE e.city_id = '312'    
;"""


pd.read_sql(c, engine)

# Reference: https://stackoverflow.com/questions/51602966/triple-join-in-sql
# Out:
#   first_name last_name                             email             address  \
# 0       MARK  RINEHART  MARK.RINEHART@sakilacustomer.org  1354 Siegen Street
#
#      city  city_id
# 0  London      312

# %% [markdown]
# 2. What query would you run to get all comedy films? Note that the genre is called the category in this schema.
# Your query should return film title, description, release year, rating, and special features.

# %%
cf = """SELECT title,description,name,release_year,rating,special_features
FROM film,category
WHERE name = 'Comedy'
;"""


pd.read_sql(cf, engine)
# Out:
#                  title                                        description  \
# 0     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 1       ACE GOLDFINGER  A Astounding Epistle of a Database Administrat...
# 2     ADAPTATION HOLES  A Astounding Reflection of a Lumberjack And a ...
# 3     AFFAIR PREJUDICE  A Fanciful Documentary of a Frisbee And a Lumb...
# 4          AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# ..                 ...                                                ...
# 995     YOUNG LANGUAGE  A Unbelieveable Yarn of a Boat And a Database ...
# 996         YOUTH KICK  A Touching Drama of a Teacher And a Cat who mu...
# 997       ZHIVAGO CORE  A Fateful Yarn of a Composer And a Man who mus...
# 998  ZOOLANDER FICTION  A Fateful Reflection of a Waitress And a Boat ...
# 999          ZORRO ARK  A Intrepid Panorama of a Mad Scientist And a B...
#
#        name  release_year rating                         special_features
# ...

# %% [markdown]
# 3. What query would you run to get all the films that Johnny Lollobrigida was in? Your query should return the actor's last name, film title, and release year.

# %%
jl = """SELECT first_name,last_name, title, release_year 
FROM film,actor
WHERE last_name = 'Lollobrigida'
;"""


pd.read_sql(jl, engine)
# Out:
#     first_name     last_name              title  release_year
# 0       JOHNNY  LOLLOBRIGIDA   ACADEMY DINOSAUR          2006
# 1       JOHNNY  LOLLOBRIGIDA     ACE GOLDFINGER          2006
# 2       JOHNNY  LOLLOBRIGIDA   ADAPTATION HOLES          2006
# 3       JOHNNY  LOLLOBRIGIDA   AFFAIR PREJUDICE          2006
# 4       JOHNNY  LOLLOBRIGIDA        AFRICAN EGG          2006
# ..         ...           ...                ...           ...
# 995     JOHNNY  LOLLOBRIGIDA     YOUNG LANGUAGE          2006
# 996     JOHNNY  LOLLOBRIGIDA         YOUTH KICK          2006
# 997     JOHNNY  LOLLOBRIGIDA       ZHIVAGO CORE          2006
# 998     JOHNNY  LOLLOBRIGIDA  ZOOLANDER FICTION          2006
# 999     JOHNNY  LOLLOBRIGIDA          ZORRO ARK          2006
#
# [1000 rows x 4 columns]

# %% [markdown]
# 4. What query would you run to get the first and last names of all the actors in the movie titled "Bingo Talented"?

# %%
bt = """SELECT first_name,last_name, title 
FROM film,actor
WHERE title = 'Bingo Talented'
;"""


pd.read_sql(bt, engine)
# Out:
#     first_name     last_name           title
# 0     PENELOPE       GUINESS  BINGO TALENTED
# 1         NICK      WAHLBERG  BINGO TALENTED
# 2           ED         CHASE  BINGO TALENTED
# 3     JENNIFER         DAVIS  BINGO TALENTED
# 4       JOHNNY  LOLLOBRIGIDA  BINGO TALENTED
# ..         ...           ...             ...
# 195       BELA        WALKEN  BINGO TALENTED
# 196      REESE          WEST  BINGO TALENTED
# 197       MARY        KEITEL  BINGO TALENTED
# 198      JULIA       FAWCETT  BINGO TALENTED
# 199      THORA        TEMPLE  BINGO TALENTED
#
# [200 rows x 3 columns]

# %% [markdown]
# 5. What query would you run to get the customer_id associated with all payments greater than twice the average payment amount? (HINT: use 2* in your query to get twice the amount). Your result should include the customer id and the amount.

# %%
ci = """SELECT customer_id, 2*AVG(amount)
FROM payment
;"""


pd.read_sql(ci, engine)
# Out:
#    customer_id  2*AVG(amount)
# 0            1       8.401335

# %% [markdown]
# 6. What query would you run to list the first and last names of the 5 customers who have the highest number(count) of payments? You can title the number of payments as num_payments.

# %%
# DESC - descending order and ASC - ascending order

cn = """SELECT first_name, last_name, payment.amount
FROM customer,payment
ORDER BY amount DESC
LIMIT 5
;"""


pd.read_sql(cn, engine)

# Reference: https://stackoverflow.com/questions/20008638/sql-order-by-from-highest-to-lowest-value
# Out:
#   first_name last_name  amount
# 0       MARY     SMITH   11.99
# 1       MARY     SMITH   11.99
# 2       MARY     SMITH   11.99
# 3       MARY     SMITH   11.99
# 4       MARY     SMITH   11.99
